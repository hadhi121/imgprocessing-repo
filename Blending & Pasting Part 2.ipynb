# %% [markdown]
# ### We have already covered how to blend and paste images of same and different sizes. But what if we want to mask part of the smaller image?

# %% [markdown]
# #### These steps may come across as a bit compilicated!

# %% [markdown]
# ### Import necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ### Read 'image3.jpg' & 'donotcopy.jpg'

# %%
img1 = cv2.imread('image3.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread('donotcopy.jpg')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### View both the images

# %%
plt.subplot(1,2,1)
plt.imshow(img1)
plt.subplot(1,2,2)
plt.imshow(img2)
plt.show()

# %% [markdown]
# ### Print the shape of both the images

# %%
print(f"Shape of Image 1 is {img1.shape}")
print(f"Shape of Image 2 is {img2.shape}")
# Out:
# Shape of Image 1 is (1920, 1080, 3)
# Shape of Image 2 is (270, 324, 3)

# %% [markdown]
# ### Set x and y offset to set the part where you want to paste the image

# %%
x_offset = 1080 - 324
y_offset = 1920 - 270

# %% [markdown]
# ### Set the region of interest

# %%
roi = img1[y_offset:1920, x_offset:1080]
plt.imshow(roi)
plt.show()

# %% [markdown]
# ### Convert the smaller image into grayscale

# %%
img2gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img2gray, cmap = 'gray')
plt.show()

# %% [markdown]
# ### Notice that letters in the image are not exactly colored in black but rather in some dark grey color. That is why we need to apply a thresholding in order to create a binary image.

# %%
ret, mask = cv2.threshold(img2gray, 120, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(mask, cmap = 'gray')

# %% [markdown]
# ### Fetch the inverse of the image using 'bitwise_or'

# %% [markdown]
# Essentially just convert all black parts of the image to white and white parts to black

# %%
mask_inv = cv2.bitwise_not(mask)

# %%
plt.imshow(mask_inv, cmap = 'gray')

# %% [markdown]
# ### Paste the inverse mask on top of original image

# %%
fg = cv2.bitwise_or(img2, img2, mask = mask_inv)

# %%
plt.imshow(fg)

# %% [markdown]
# ### Paste the mask on top of our region of interest

# %%
bg = cv2.bitwise_or(roi, roi, mask = mask)

# %%
plt.imshow(bg)

# %% [markdown]
# ### Add our foreground & background image

# %%
final_roi = cv2.add(fg, bg)

# %%
plt.imshow(final_roi)

# %% [markdown]
# ### Paste the final roi on top of our original Image

# %%
img1[y_offset:1920, x_offset:1080] = final_roi

# %%
plt.imshow(img1)

# %% [markdown]
# ***

# %% [markdown]
# # <center><a href = "http://edure.in/"><span style = "color:CornflowerBlue; font-family:Courier New;font-size:40px">EDURE LEARNING</span></a></center>
